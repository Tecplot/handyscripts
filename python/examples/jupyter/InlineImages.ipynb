# %%
import os
from os import path
import tecplot as tp

# %%
examples_dir = tp.session.tecplot_examples_directory()
tp.load_layout(path.join(examples_dir,'SimpleData','F18.lay'))
frame = tp.active_frame()
tp.extension.ipython.show(frame)
